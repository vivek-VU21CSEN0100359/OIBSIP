# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-VU21CSEN0100359/OIBSIP/blob/main/Project_1_D2_L1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/sample_data/menu.csv")
df.head(10)
# Out:
#     Category                                               Item  \
# 0  Breakfast                                       Egg McMuffin
# 1  Breakfast                                  Egg White Delight
# 2  Breakfast                                   Sausage McMuffin
# 3  Breakfast                          Sausage McMuffin with Egg
# 4  Breakfast                   Sausage McMuffin with Egg Whites
# 5  Breakfast                               Steak & Egg McMuffin
# 6  Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7  Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
#
#      Serving Size  Calories  Calories from Fat  Total Fat  \
# 0  4.8 oz (136 g)       300                120       13.0
# 1  4.8 oz (135 g)       250                 70        8.0
# 2  3.9 oz (111 g)       370                200       23.0
# 3  5.7 oz (161 g)       450                250       28.0
# 4  5.7 oz (161 g)       400                210       23.0
# 5  6.5 oz (185 g)       430                210       23.0
# 6  5.3 oz (150 g)       460                230       26.0
# 7  5.8 oz (164 g)       520                270       30.0
# 8  5.4 oz (153 g)       410                180       20.0
# 9  5.9 oz (167 g)       470                220       25.0
#
#    Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                         20            5.0                             25
# 1                         12            3.0                             15
# 2                         35            8.0                             42
# 3                         43           10.0                             52
# 4                         35            8.0                             42
# 5                         36            9.0                             46
# 6                         40           13.0                             65
# 7                         47           14.0                             68
# 8                         32           11.0                             56
# 9                         38           12.0                             59
#
#    Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0        0.0  ...             31                             10
# 1        0.0  ...             30                             10
# 2        0.0  ...             29                             10
# 3        0.0  ...             30                             10
# 4        0.0  ...             30                             10
# 5        1.0  ...             31                             10
# 6        0.0  ...             38                             13
# 7        0.0  ...             43                             14
# 8        0.0  ...             36                             12
# 9        0.0  ...             42                             14
#
#    Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0              4                             17       3       17
# 1              4                             17       3       18
# 2              4                             17       2       14
# 3              4                             17       2       21
# 4              4                             17       2       21
# 5              4                             18       3       26
# 6              2                              7       3       19
# 7              3                             12       4       19
# 8              2                              7       3       20
# 9              3                             12       4       20
#
#    Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                         10                          0
# 1                          6                          0
# 2                          8                          0
# 3                         15                          0
# 4                          6                          0
# 5                         15                          2
# 6                         10                          8
# 7                         15                          8
# 8                          2                          8
# 9                          6                          8
#
#    Calcium (% Daily Value)  Iron (% Daily Value)
# 0                       25                    15
# 1                       25                     8
# 2                       25                    10
# 3                       30                    15
# 4                       25                    10
# 5                       30                    20
# 6                       15                    15
# 7                       20                    20
# 8                       15                    10
# 9                       15                    15
#
# [10 rows x 24 columns]

# %%
food=pd.read_csv('/content/sample_data/menu.csv')

# %%
food
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 0     4.8 oz (136 g)       300                120       13.0
# 1     4.8 oz (135 g)       250                 70        8.0
# 2     3.9 oz (111 g)       370                200       23.0
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# ..               ...       ...                ...        ...
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                           20            5.0                             25
# 1                           12            3.0                             15
# 2                           35            8.0                             42
# 3                           43           10.0                             52
# 4                           35            8.0                             42
# ..                         ...            ...                            ...
# 255                         26            9.0                             44
# 256                         35           12.0                             58
# 257                         17            6.0                             29
# 258                         50           15.0                             76
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0          0.0  ...             31                             10
# 1          0.0  ...             30                             10
# 2          0.0  ...             29                             10
# 3          0.0  ...             30                             10
# 4          0.0  ...             30                             10
# ..         ...  ...            ...                            ...
# 255        0.5  ...             80                             27
# 256        1.0  ...            106                             35
# 257        0.0  ...             53                             18
# 258        1.0  ...            114                             38
# 259        0.0  ...             57                             19
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0                4                             17       3       17
# 1                4                             17       3       18
# 2                4                             17       2       14
# 3                4                             17       2       21
# 4                4                             17       2       21
# ..             ...                            ...     ...      ...
# 255              1                              4      64       12
# 256              1                              5      85       15
# 257              1                              2      43        8
# 258              2                              9     103       21
# 259              1                              5      51       10
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                           10                          0
# 1                            6                          0
# 2                            8                          0
# 3                           15                          0
# 4                            6                          0
# ..                         ...                        ...
# 255                         15                          0
# 256                         20                          0
# 257                         10                          0
# 258                         20                          0
# 259                         10                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                         25                    15
# 1                         25                     8
# 2                         25                    10
# 3                         30                    15
# 4                         25                    10
# ..                       ...                   ...
# 255                       40                     8
# 256                       50                    10
# 257                       25                     6
# 258                       60                     6
# 259                       30                     4
#
# [260 rows x 24 columns]

# %%
print("Dimension of the dataset:", food.shape)
print("Size of the dataset: ", food.size)
print("Columns in the dataset: ", food.keys())
# Out:
# Dimension of the dataset: (260, 24)
# Size of the dataset:  6240
# Columns in the dataset:  Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
print("Information of the dataset: \n",food.info())
print("After removing duplicates: \n",food.drop_duplicates(inplace=True))
print("Size of the dataset after removing duplicates: \n",food.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
#  12  Sodium                         260 non-null    int64
#  13  Sodium (% Daily Value)         260 non-null    int64
#  14  Carbohydrates                  260 non-null    int64
#  15  Carbohydrates (% Daily Value)  260 non-null    int64
#  16  Dietary Fiber                  260 non-null    int64
#  17  Dietary Fiber (% Daily Value)  260 non-null    int64
#  18  Sugars                         260 non-null    int64
#  19  Protein                        260 non-null    int64
#  20  Vitamin A (% Daily Value)      260 non-null    int64
#  21  Vitamin C (% Daily Value)      260 non-null    int64
#  22  Calcium (% Daily Value)        260 non-null    int64
#  23  Iron (% Daily Value)           260 non-null    int64
# dtypes: float64(3), int64(18), object(3)
# memory usage: 48.9+ KB
# Information of the dataset:
#  None
# After removing duplicates:
#  None
# Size of the dataset after removing duplicates:
#  6240

# %%
print("Description of the dataset: \n",food.describe())
# Out:
# Description of the dataset:
#            Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# std         5.321873                      26.639209    0.429133    87.269257
# min         0.000000                       0.000000    0.000000     0.000000
# 25%         1.000000                       4.750000    0.000000     5.000000
# 50%         5.000000                      24.000000    0.000000    35.000000
# 75%        10.000000                      48.000000    0.000000    65.000000
# max        20.000000                     102.000000    2.500000   575.000000
#
#        Cholesterol (% Daily Value)       Sodium  ...  Carbohydrates  \
# count                   260.000000   260.000000  ...     260.000000
# mean                     18.392308   495.750000  ...      47.346154
# std                      29.091653   577.026323  ...      28.252232
# min                       0.000000     0.000000  ...       0.000000
# 25%                       2.000000   107.500000  ...      30.000000
# 50%                      11.000000   190.000000  ...      44.000000
# 75%                      21.250000   865.000000  ...      60.000000
# max                     192.000000  3600.000000  ...     141.000000
#
#        Carbohydrates (% Daily Value)  Dietary Fiber  \
# count                     260.000000     260.000000
# mean                       15.780769       1.630769
# std                         9.419544       1.567717
# min                         0.000000       0.000000
# 25%                        10.000000       0.000000
# 50%                        15.000000       1.000000
# 75%                        20.000000       3.000000
# max                        47.000000       7.000000
#
#        Dietary Fiber (% Daily Value)      Sugars     Protein  \
# count                     260.000000  260.000000  260.000000
# mean                        6.530769   29.423077   13.338462
# std                         6.307057   28.679797   11.426146
# min                         0.000000    0.000000    0.000000
# 25%                         0.000000    5.750000    4.000000
# 50%                         5.000000   17.500000   12.000000
# 75%                        10.000000   48.000000   19.000000
# max                        28.000000  128.000000   87.000000
#
#        Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# count                 260.000000                 260.000000
# mean                   13.426923                   8.534615
# std                    24.366381                  26.345542
# min                     0.000000                   0.000000
# 25%                     2.000000                   0.000000
# 50%                     8.000000                   0.000000
# 75%                    15.000000                   4.000000
# max                   170.000000                 240.000000
#
#        Calcium (% Daily Value)  Iron (% Daily Value)
# count               260.000000            260.000000
# mean                 20.973077              7.734615
# std                  17.019953              8.723263
# min                   0.000000              0.000000
# 25%                   6.000000              0.000000
# 50%                  20.000000              4.000000
# 75%                  30.000000             15.000000
# max                  70.000000             40.000000
#
# [8 rows x 21 columns]

# %%
category_counts = food['Category'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('Proportion of Different Categories')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(x='Category', y='Calories', data=food)
plt.xticks(rotation=45)
plt.title('Calories by Category')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.show()

# %%
food['Calories'].idxmax()
# Out:
# 82

# %%
food.at[82, 'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
food['Protein'].idxmax()
# Out:
# 82

# %%
food['Cholesterol'].idxmax()
# Out:
# 31

# %%
food.at[31, 'Item']
# Out:
# 'Big Breakfast with Hotcakes (Regular Biscuit)'

# %%
food[['Saturated Fat (% Daily Value)','Saturated Fat']].idxmax()
# Out:
# Saturated Fat (% Daily Value)    253
# Saturated Fat                     32
# dtype: int64

# %%
value_1 = food.iloc[253, 1]
value_2 = food.iloc[32, 1]
print(value_1," ", value_2)
# Out:
# McFlurry with M&M’s Candies (Medium)   Big Breakfast with Hotcakes (Large Biscuit)

# %%
item_with_highest_calories = food.loc[food.groupby(['Category'])['Calories'].idxmax()]
item_with_highest_calories_sorted = item_with_highest_calories.sort_values(by='Calories', ascending=False)[['Category','Item', 'Calories']]
print(item_with_highest_calories_sorted)
# Out:
#                Category                                         Item  Calories
# 82       Chicken & Fish                 Chicken McNuggets (40 piece)      1880
# 32            Breakfast  Big Breakfast with Hotcakes (Large Biscuit)      1150
# 253  Smoothies & Shakes         McFlurry with M&M’s Candies (Medium)       930
# 231        Coffee & Tea                Frappé Chocolate Chip (Large)       760
# 47          Beef & Pork           Double Quarter Pounder with Cheese       750
# 98       Snacks & Sides                           Large French Fries       510
# 88               Salads  Premium Southwest Salad with Crispy Chicken       450
# 108            Desserts                           Hot Caramel Sundae       340
# 112           Beverages                    Coca-Cola Classic (Large)       280

# %%
item_with_lowest_calories = food.loc[food.groupby(['Category'])['Calories'].idxmin()]
item_with_lowest_calories_sorted = item_with_lowest_calories.sort_values(by='Calories', ascending=False)[['Category','Item', 'Calories']]
print(item_with_lowest_calories_sorted)
# Out:
#                Category                                         Item  Calories
# 48          Beef & Pork                                    Hamburger       240
# 235  Smoothies & Shakes           Strawberry Banana Smoothie (Small)       210
# 78       Chicken & Fish                  Chicken McNuggets (4 piece)       190
# 38            Breakfast                                   Hash Brown       150
# 84               Salads  Premium Bacon Ranch Salad (without Chicken)       140
# 106            Desserts                          Kids Ice Cream Cone        45
# 101      Snacks & Sides                                 Apple Slices        15
# 114           Beverages                            Diet Coke (Small)         0
# 137        Coffee & Tea                             Iced Tea (Small)         0

# %%
def plot_histogram(column, bins=30):
    plt.figure(figsize=(10, 6))
    sns.histplot(food[column], bins=bins, kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

columns_to_plot = ['Calories', 'Total Fat', 'Saturated Fat', 'Cholesterol', 'Sodium', 'Carbohydrates', 'Sugars', 'Protein']
for column in columns_to_plot:
    plot_histogram(column)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=food['Calories'], y=food['Protein'])
plt.title('Calories vs Protein')
plt.xlabel('Calories')
plt.ylabel('Protein')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=food['Calories'], y=food['Total Fat'])
plt.title('Calories vs Total Fat')
plt.xlabel('Calories')
plt.ylabel('Total Fat')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=food['Calories'], y=food['Sugars'])
plt.title('Calories vs Sugar')
plt.xlabel('Calories')
plt.ylabel('Sugar')
plt.show()

# %%
plot=sns.stripplot(x="Category", y='Sugars', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Sugar Content')
plt.show()

# %%
plot=sns.stripplot(x="Category", y='Sodium', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Sodium Content')
plt.show()

# %%
plot=sns.stripplot(x="Category", y='Protein', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Protein Content')
plt.show()

# %%
plot=sns.stripplot(x="Category", y='Total Fat', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Total Fat Content')
plt.show()

# %%
plot=sns.stripplot(x="Category", y='Cholesterol', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Cholesterol Content')
plt.show()

# %%
numeric_data = food.select_dtypes(include=['float64', 'int64'])

# Correlation Heatmap
plt.figure(figsize=(14, 10))
correlation_matrix = numeric_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Nutritional Values')
plt.show()

# %%
sorted_items_by_calories = food.sort_values(by=['Category', 'Calories'], ascending=[True, False]) #Sort by Calories

# Print the sorted items by category
for category, items in sorted_items_by_calories.groupby('Category'):
    pd.set_option('display.max_rows', None)  # Show all rows
    pd.set_option('display.max_columns', None)  # Show all columns
    pd.set_option('display.width', None) #Auto-adjust width
    print(f"Category: {category}")
    print(items[['Item', 'Calories']])
    print("\n")

# Create a bar plot to show the top items with the highest calories in each category
plt.figure(figsize=(12, 6))
top_items = sorted_items_by_calories.groupby('Category').head(1)  # Select top item in each category
plt.bar(top_items['Category'], top_items['Calories'], color='skyblue')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.title('Top Item with Highest Calories in Each Category')
plt.xticks(rotation=45)
plt.show()

# Create a pie chart to show the distribution of calories among different categories
plt.figure(figsize=(8, 8))
total_calories_per_category = food.groupby('Category')['Calories'].sum()
plt.pie(total_calories_per_category, labels=total_calories_per_category.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.axis('equal')
plt.title('Calories Distribution by Category')
plt.show()
# Out:
# Category: Beef & Pork
#                                          Item  Calories
# 47         Double Quarter Pounder with Cheese       750
# 51                     Bacon Clubhouse Burger       720
# 45  Quarter Pounder with Bacon Habanero Ranch       610
# 44        Quarter Pounder with Bacon & Cheese       600
# 46                     Quarter Pounder Deluxe       540
# 42                                    Big Mac       530
# 43                Quarter Pounder with Cheese       520
# 56                                      McRib       500
# 53                             Bacon McDouble       440
# 50                        Double Cheeseburger       430
# 54                               Daily Double       430
# 55                            Jalapeño Double       430
# 52                                   McDouble       380
# 49                               Cheeseburger       290
# 48                                  Hamburger       240
#
#
# Category: Beverages
#                                   Item  Calories
# 112          Coca-Cola Classic (Large)       280
# 128                     Sprite (Large)       280
# 135   Minute Maid Orange Juice (Large)       280
# 120                  Dr Pepper (Large)       270
# 111         Coca-Cola Classic (Medium)       200
# 127                    Sprite (Medium)       200
# 119                 Dr Pepper (Medium)       190
# 134  Minute Maid Orange Juice (Medium)       190
# 133   Minute Maid Orange Juice (Small)       150
# 110          Coca-Cola Classic (Small)       140
# 118                  Dr Pepper (Small)       140
# 126                     Sprite (Small)       140
# 131        Fat Free Chocolate Milk Jug       130
# 113          Coca-Cola Classic (Child)       100
# 121                  Dr Pepper (Child)       100
# 129                     Sprite (Child)       100
# 130                1% Low Fat Milk Jug       100
# 132   Minute Maid 100% Apple Juice Box        80
# 114                  Diet Coke (Small)         0
# 115                 Diet Coke (Medium)         0
# 116                  Diet Coke (Large)         0
# 117                  Diet Coke (Child)         0
# 122             Diet Dr Pepper (Small)         0
# 123            Diet Dr Pepper (Medium)         0
# 124             Diet Dr Pepper (Large)         0
# 125             Diet Dr Pepper (Child)         0
# 136                Dasani Water Bottle         0
#
#
# Category: Breakfast
#                                                  Item  Calories
# 32        Big Breakfast with Hotcakes (Large Biscuit)      1150
# 31      Big Breakfast with Hotcakes (Regular Biscuit)      1090
# 34  Big Breakfast with Hotcakes and Egg Whites (La...      1050
# 33  Big Breakfast with Hotcakes and Egg Whites (Re...       990
# 28                      Big Breakfast (Large Biscuit)       800
# 27                    Big Breakfast (Regular Biscuit)       740
# 30      Big Breakfast with Egg Whites (Large Biscuit)       690
# 26                          Steak, Egg & Cheese Bagel       670
# 29    Big Breakfast with Egg Whites (Regular Biscuit)       640
# 24                          Bacon, Egg & Cheese Bagel       620
# 13           Sausage Biscuit with Egg (Large Biscuit)       570
# 25          Bacon, Egg & Cheese Bagel with Egg Whites       570
# 22                   Sausage, Egg & Cheese McGriddles       550
# 18              Steak & Egg Biscuit (Regular Biscuit)       540
# 7         Bacon, Egg & Cheese Biscuit (Large Biscuit)       520
# 15    Sausage Biscuit with Egg Whites (Large Biscuit)       520
# 36                               Hotcakes and Sausage       520
# 12         Sausage Biscuit with Egg (Regular Biscuit)       510
# 23   Sausage, Egg & Cheese McGriddles with Egg Whites       500
# 11                    Sausage Biscuit (Large Biscuit)       480
# 9   Bacon, Egg & Cheese Biscuit with Egg Whites (L...       470
# 17     Southern Style Chicken Biscuit (Large Biscuit)       470
# 6       Bacon, Egg & Cheese Biscuit (Regular Biscuit)       460
# 14  Sausage Biscuit with Egg Whites (Regular Biscuit)       460
# 19                     Bacon, Egg & Cheese McGriddles       460
# 39                                     Cinnamon Melts       460
# 3                           Sausage McMuffin with Egg       450
# 5                                Steak & Egg McMuffin       430
# 10                  Sausage Biscuit (Regular Biscuit)       430
# 21                                 Sausage McGriddles       420
# 8   Bacon, Egg & Cheese Biscuit with Egg Whites (R...       410
# 16   Southern Style Chicken Biscuit (Regular Biscuit)       410
# 4                    Sausage McMuffin with Egg Whites       400
# 20     Bacon, Egg & Cheese McGriddles with Egg Whites       400
# 2                                    Sausage McMuffin       370
# 35                                           Hotcakes       350
# 0                                        Egg McMuffin       300
# 37                                    Sausage Burrito       300
# 40                              Fruit & Maple Oatmeal       290
# 41          Fruit & Maple Oatmeal without Brown Sugar       260
# 1                                   Egg White Delight       250
# 38                                         Hash Brown       150
#
#
# Category: Chicken & Fish
#                                                  Item  Calories
# 82                       Chicken McNuggets (40 piece)      1880
# 81                       Chicken McNuggets (20 piece)       940
# 63            Bacon Clubhouse Crispy Chicken Sandwich       750
# 59               Premium Crispy Chicken Club Sandwich       670
# 74  Premium McWrap Southwest Chicken (Crispy Chicken)       670
# 70    Premium McWrap Chicken & Bacon (Crispy Chicken)       630
# 61          Premium Crispy Chicken Ranch BLT Sandwich       610
# 72    Premium McWrap Chicken & Ranch (Crispy Chicken)       610
# 64           Bacon Clubhouse Grilled Chicken Sandwich       590
# 76  Premium McWrap Chicken Sweet Chili (Crispy Chi...       540
# 75  Premium McWrap Southwest Chicken (Grilled Chic...       520
# 57            Premium Crispy Chicken Classic Sandwich       510
# 60              Premium Grilled Chicken Club Sandwich       510
# 67                            Bacon Cheddar McChicken       480
# 71   Premium McWrap Chicken & Bacon (Grilled Chicken)       480
# 80                       Chicken McNuggets (10 piece)       470
# 62         Premium Grilled Chicken Ranch BLT Sandwich       450
# 73   Premium McWrap Chicken & Ranch (Grilled Chicken)       450
# 65             Southern Style Crispy Chicken Sandwich       430
# 68                      Bacon Buffalo Ranch McChicken       430
# 83                                       Filet-O-Fish       390
# 77  Premium McWrap Chicken Sweet Chili (Grilled Ch...       380
# 66                                          McChicken       360
# 69                            Buffalo Ranch McChicken       360
# 58           Premium Grilled Chicken Classic Sandwich       350
# 79                        Chicken McNuggets (6 piece)       280
# 78                        Chicken McNuggets (4 piece)       190
#
#
# Category: Coffee & Tea
#                                                   Item  Calories
# 231                      Frappé Chocolate Chip (Large)       760
# 225                               Frappé Mocha (Large)       670
# 228                             Frappé Caramel (Large)       670
# 230                     Frappé Chocolate Chip (Medium)       630
# 224                              Frappé Mocha (Medium)       550
# 227                            Frappé Caramel (Medium)       550
# 192                              Hot Chocolate (Large)       540
# 229                      Frappé Chocolate Chip (Small)       530
# 180                                      Mocha (Large)       500
# 186                              Caramel Mocha (Large)       480
# 213                                 Iced Mocha (Large)       480
# 219                         Iced Caramel Mocha (Large)       460
# 223                               Frappé Mocha (Small)       450
# 226                             Frappé Caramel (Small)       450
# 191                             Hot Chocolate (Medium)       440
# 153                              Caramel Latte (Large)       430
# 156                             Hazelnut Latte (Large)       430
# 159                       French Vanilla Latte (Large)       420
# 179                                     Mocha (Medium)       410
# 195             Hot Chocolate with Nonfat Milk (Large)       400
# 183                     Mocha with Nonfat Milk (Large)       390
# 185                             Caramel Mocha (Medium)       390
# 216                Iced Mocha with Nonfat Milk (Large)       390
# 189                       Nonfat Caramel Mocha (Large)       370
# 222                  Iced Nonfat Caramel Mocha (Large)       370
# 190                              Hot Chocolate (Small)       360
# 212                                Iced Mocha (Medium)       350
# 152                             Caramel Latte (Medium)       340
# 178                                      Mocha (Small)       340
# 194            Hot Chocolate with Nonfat Milk (Medium)       340
# 218                        Iced Caramel Mocha (Medium)       340
# 155                            Hazelnut Latte (Medium)       330
# 158                      French Vanilla Latte (Medium)       330
# 162  Latte with Sugar Free French Vanilla Syrup (La...       330
# 182                    Mocha with Nonfat Milk (Medium)       330
# 184                              Caramel Mocha (Small)       320
# 168                       Nonfat Caramel Latte (Large)       310
# 171                      Nonfat Hazelnut Latte (Large)       310
# 188                      Nonfat Caramel Mocha (Medium)       310
# 174                Nonfat French Vanilla Latte (Large)       300
# 211                                 Iced Mocha (Small)       290
# 215               Iced Mocha with Nonfat Milk (Medium)       290
# 150                                      Latte (Large)       280
# 193             Hot Chocolate with Nonfat Milk (Small)       280
# 217                         Iced Caramel Mocha (Small)       280
# 151                              Caramel Latte (Small)       270
# 154                             Hazelnut Latte (Small)       270
# 181                     Mocha with Nonfat Milk (Small)       270
# 198                        Regular Iced Coffee (Large)       270
# 221                 Iced Nonfat Caramel Mocha (Medium)       270
# 157                       French Vanilla Latte (Small)       260
# 161  Latte with Sugar Free French Vanilla Syrup (Me...       260
# 201                        Caramel Iced Coffee (Large)       260
# 167                      Nonfat Caramel Latte (Medium)       250
# 170                     Nonfat Hazelnut Latte (Medium)       250
# 187                       Nonfat Caramel Mocha (Small)       250
# 204                       Hazelnut Iced Coffee (Large)       250
# 173               Nonfat French Vanilla Latte (Medium)       240
# 207                 French Vanilla Iced Coffee (Large)       240
# 214                Iced Mocha with Nonfat Milk (Small)       240
# 220                  Iced Nonfat Caramel Mocha (Small)       230
# 143                                  Sweet Tea (Large)       220
# 177  Nonfat Latte with Sugar Free French Vanilla Sy...       220
# 149                                     Latte (Medium)       210
# 160  Latte with Sugar Free French Vanilla Syrup (Sm...       210
# 166                       Nonfat Caramel Latte (Small)       200
# 169                      Nonfat Hazelnut Latte (Small)       200
# 172                Nonfat French Vanilla Latte (Small)       190
# 197                       Regular Iced Coffee (Medium)       190
# 142                                 Sweet Tea (Medium)       180
# 200                       Caramel Iced Coffee (Medium)       180
# 203                      Hazelnut Iced Coffee (Medium)       180
# 148                                      Latte (Small)       170
# 165                               Nonfat Latte (Large)       170
# 176  Nonfat Latte with Sugar Free French Vanilla Sy...       170
# 206                French Vanilla Iced Coffee (Medium)       170
# 210  Iced Coffee with Sugar Free French Vanilla Syr...       160
# 141                                  Sweet Tea (Small)       150
# 175  Nonfat Latte with Sugar Free French Vanilla Sy...       140
# 196                        Regular Iced Coffee (Small)       140
# 164                              Nonfat Latte (Medium)       130
# 199                        Caramel Iced Coffee (Small)       130
# 202                       Hazelnut Iced Coffee (Small)       130
# 205                 French Vanilla Iced Coffee (Small)       120
# 209  Iced Coffee with Sugar Free French Vanilla Syr...       120
# 144                                  Sweet Tea (Child)       110
# 163                               Nonfat Latte (Small)       100
# 208  Iced Coffee with Sugar Free French Vanilla Syr...        80
# 137                                   Iced Tea (Small)         0
# 138                                  Iced Tea (Medium)         0
# 139                                   Iced Tea (Large)         0
# 140                                   Iced Tea (Child)         0
# 145                                     Coffee (Small)         0
# 146                                    Coffee (Medium)         0
# 147                                     Coffee (Large)         0
#
#
# Category: Desserts
#                       Item  Calories
# 108     Hot Caramel Sundae       340
# 107       Hot Fudge Sundae       330
# 109      Strawberry Sundae       280
# 103        Baked Apple Pie       250
# 104  Chocolate Chip Cookie       160
# 105  Oatmeal Raisin Cookie       150
# 106    Kids Ice Cream Cone        45
#
#
# Category: Salads
#                                               Item  Calories
# 88     Premium Southwest Salad with Crispy Chicken       450
# 85   Premium Bacon Ranch Salad with Crispy Chicken       380
# 89    Premium Southwest Salad with Grilled Chicken       290
# 86  Premium Bacon Ranch Salad with Grilled Chicken       220
# 84     Premium Bacon Ranch Salad (without Chicken)       140
# 87       Premium Southwest Salad (without Chicken)       140
#
#
# Category: Smoothies & Shakes
#                                                   Item  Calories
# 253               McFlurry with M&M’s Candies (Medium)       930
# 246                           Strawberry Shake (Large)       850
# 249                            Chocolate Shake (Large)       850
# 243                              Vanilla Shake (Large)       820
# 251                             Shamrock Shake (Large)       820
# 258  McFlurry with Reese's Peanut Butter Cups (Medium)       810
# 248                           Chocolate Shake (Medium)       700
# 245                          Strawberry Shake (Medium)       690
# 256                McFlurry with Oreo Cookies (Medium)       690
# 242                             Vanilla Shake (Medium)       660
# 250                            Shamrock Shake (Medium)       660
# 252                McFlurry with M&M’s Candies (Small)       650
# 247                            Chocolate Shake (Small)       560
# 244                           Strawberry Shake (Small)       550
# 241                              Vanilla Shake (Small)       530
# 255                 McFlurry with Oreo Cookies (Small)       510
# 254                McFlurry with M&M’s Candies (Snack)       430
# 259   McFlurry with Reese's Peanut Butter Cups (Snack)       410
# 234             Blueberry Pomegranate Smoothie (Large)       340
# 240                   Mango Pineapple Smoothie (Large)       340
# 257                 McFlurry with Oreo Cookies (Snack)       340
# 237                 Strawberry Banana Smoothie (Large)       330
# 233            Blueberry Pomegranate Smoothie (Medium)       260
# 239                  Mango Pineapple Smoothie (Medium)       260
# 236                Strawberry Banana Smoothie (Medium)       250
# 232             Blueberry Pomegranate Smoothie (Small)       220
# 235                 Strawberry Banana Smoothie (Small)       210
# 238                   Mango Pineapple Smoothie (Small)       210
#
#
# Category: Snacks & Sides
#                                            Item  Calories
# 98                           Large French Fries       510
# 94            Ranch Snack Wrap (Crispy Chicken)       360
# 90     Chipotle BBQ Snack Wrap (Crispy Chicken)       340
# 97                          Medium French Fries       340
# 92    Honey Mustard Snack Wrap (Crispy Chicken)       330
# 95           Ranch Snack Wrap (Grilled Chicken)       280
# 91    Chipotle BBQ Snack Wrap (Grilled Chicken)       260
# 93   Honey Mustard Snack Wrap (Grilled Chicken)       250
# 96                           Small French Fries       230
# 102                     Fruit 'n Yogurt Parfait       150
# 99                            Kids French Fries       110
# 100                                  Side Salad        20
# 101                                Apple Slices        15

# %%
recommendations = """
1. Highlight and promote items with lower calorie counts to cater to health-conscious customers.
2. Implement marketing campaigns to promote the healthier options in the menu, such as salads and fruit items.
3. Introduce limited-time offers on high-protein items to attract fitness enthusiasts.
4. Analyze the nutritional content trends to identify items that could be reformulated for better health benefits.
5. Provide clear labeling and educational content on the menu about the nutritional facts to help customers make informed choices.
6. Offer combo deals that include healthier sides, such as apple slices or salads, with popular main items.
7. Conduct customer surveys to understand preferences for specific nutritional aspects, like low-fat or low-carb options.
8. Promote breakfast items with balanced nutrition to attract morning customers.
9. Track seasonal trends in sales to adjust the menu offerings and marketing strategies accordingly.
10. Consider demographic-specific marketing strategies, such as promoting items popular among different age groups or dietary preferences.
"""

print(recommendations)
# Out:
# 1. Highlight and promote items with lower calorie counts to cater to health-conscious customers.
# 2. Implement marketing campaigns to promote the healthier options in the menu, such as salads and fruit items.
# 3. Introduce limited-time offers on high-protein items to attract fitness enthusiasts.
# 4. Analyze the nutritional content trends to identify items that could be reformulated for better health benefits.
# 5. Provide clear labeling and educational content on the menu about the nutritional facts to help customers make informed choices.
# 6. Offer combo deals that include healthier sides, such as apple slices or salads, with popular main items.
# 7. Conduct customer surveys to understand preferences for specific nutritional aspects, like low-fat or low-carb options.
# 8. Promote breakfast items with balanced nutrition to attract morning customers.
# 9. Track seasonal trends in sales to adjust the menu offerings and marketing strategies accordingly.
# 10. Consider demographic-specific marketing strategies, such as promoting items popular among different age groups or dietary preferences.
